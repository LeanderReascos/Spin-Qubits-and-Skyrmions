# %%
import sympy as sp
import numpy as np

from SymPT import * 

from IPython.display import display, Math, Latex, Markdown

# %% [markdown]
# # Defining H

# %%
# ------------- Defining the symbols for the Hamiltonian ----------------
hbar = sp.symbols('hbar', positive=True, real=True)
omega_x = sp.symbols('omega_x', positive=True, real=True) # Frequency of x confinement
lx = sp.Symbol('l_x', positive=True, real=True)         # Length of x confinement
m = sp.Symbol('m', positive=True, real=True)                    # Effective mass of the particle on Si

ky = RDSymbol('k_y', positive=True, real=True)  
kB = RDSymbol('k_B', positive=True, real=True)  
B = sp.symbols('B', real=True)          # Total Magnetic field perpendicular to the plane of xy confinement B = B0 + b0, where b0 is genereted by the skyrmion
omega_y = omega_x / ky                  # Frequency of y confinement in terms of omega_x
omega_c = - omega_x / kB                # Frequency of omega_c = eB/m in terms of omega_x


# Effective frequencies affter diagonalization of H0 using the minimal coupling substitution
kp = sp.symbols('k_+', positive=True, real=True)
km = sp.symbols('k_-', positive=True, real=True)
# Omega_3_2 = sp.sqrt((omega_x**2 - omega_y**2)**2 + 2 * omega_c**2 * (omega_x**2 + omega_y**2) + omega_c**4)
omega_p = omega_x / kp              #1/sp.sqrt(2) * sp.sqrt(omega_x**2 + omega_y**2 + omega_c**2 + Omega_3_2)
omega_m = omega_x / km              #1/sp.sqrt(2) * sp.sqrt(omega_x**2 + omega_y**2 + omega_c**2 - Omega_3_2)

# -----------------------------------------------------------------------------
# Auxilliary variables
Kp = sp.symbols('K_+', positive=True, real=True)
Km = sp.symbols('K_-', positive=True, real=True)

subs_Kp = {
    Kp : 2 * kp / (kp**2 + 1),
    Km : 2 * km / (km**2 + 1)
}

# %%
# ------------- Defining the position momentum basis for the Hamiltonian ----------------
# Defining the bosonic operators of the new basis after diagonalization of H0
# a_+ and a_- are the bosonic operators of the new basis

a_1 = BosonOp('a_+')
ad_1 = Dagger(a_1)
a_2 = BosonOp('a_-')
ad_2 = Dagger(a_2)

# -----------------------------------------------------------------------------
# Defining the position operators x and y in the new basis after diagonalization of H0 and using the bosonic operators of the new basis
theta = sp.Symbol('theta', real=True)               # Parameter used on the diagonalization of H0
beta = - hbar / lx**2 * sp.sqrt(1 / (Kp*Km*ky))     # Parameter used on the diagonalization of H0
alpha = 1 / beta

c1_Omega1 = Kp / omega_x
c2_Omega2 = Kp * ky / omega_x

# Substitutions for the lenghts of the confinement
subs_lenght = {
    sp.sqrt(hbar / (m * omega_x)): lx,
    sp.sqrt( m * omega_x / hbar): 1 / lx,
    sp.sqrt( m * omega_x * hbar): hbar / lx,
}

# Position Operators
x = Operator('x')
y = Operator('y')
px = Operator('p_x')
py = Operator('p_y')

# Position operators in the new basis
x_T = (sp.sqrt(hbar/(2*m) * c1_Omega1) * sp.cos(theta) * (ad_1 + a_1) - sp.I * sp.sqrt(hbar*m * 1 / (2 * c2_Omega2)) * alpha * sp.sin(theta) * (ad_2 - a_2)).subs(subs_lenght)
y_T = (sp.sqrt(hbar/(2*m) * c2_Omega2) * sp.cos(theta) * (ad_2 + a_2) - sp.I * sp.sqrt(hbar*m * 1 / (2 * c1_Omega1)) * alpha * sp.sin(theta) * (ad_1 - a_1)).subs(subs_lenght)
px_T = (sp.sqrt(hbar/(2*m)* c2_Omega2) * beta * sp.sin(theta) * (ad_2 + a_2) + sp.I * sp.sqrt(hbar * m * 1 / (2 * c1_Omega1)) * sp.cos(theta) * (ad_1 - a_1)).subs(subs_lenght)
py_T = (sp.sqrt(hbar/(2*m)* c1_Omega1) * beta * sp.sin(theta) * (ad_1 + a_1) + sp.I * sp.sqrt(hbar * m * 1 / (2 * c2_Omega2)) * sp.cos(theta) * (ad_2 - a_2)).subs(subs_lenght)

transformation = {
    x : x_T,
    y : y_T,
    px : px_T,
    py : py_T
}

a, b = sp.symbols('a b', real=True, positive=True)
subs_theta = {
    theta : sp.Rational(1,2) * sp.atan(-a/b)
}

subs_theta.update({
    sp.cos(theta) * sp.sin(theta) : (sp.cos(theta) * sp.sin(theta)).subs(subs_theta).trigsimp().simplify(),
    sp.sin(theta)**2 : (sp.sin(theta)**2).subs(subs_theta).trigsimp().simplify(),
    sp.cos(theta)**2 : (sp.cos(theta)**2).subs(subs_theta).trigsimp().simplify(),
})

subs_ab = {
    sp.sqrt(a**2 + b**2) : (1/kp**2 - 1/km**2).factor(),
    a : 2 / kB * sp.sqrt(1 / (Kp*Km*ky)),
    b : (ky**2 - 1) / ky**2,
}

display_dict(transformation)

# -----------------------------------------------------------------------------
# ------------- Defining the spin basis for the Hamiltonian ----------------

Spin = RDBasis('sigma', 2)
s0, sx, sy, sz = Spin.basis # Pauli operators
# Out:
# $\displaystyle x : \frac{\sqrt{2} \sqrt{K_{+}} l_{x} \cos{\left(\theta \right)} \left({{a_+}^\dagger} + {a_+}\right)}{2} + \frac{\sqrt{2} i \sqrt{K_{-}} l_{x} \sin{\left(\theta \right)} \left({{a_-}^\dagger} - {a_-}\right)}{2}$
# $\displaystyle y : \frac{\sqrt{2} \sqrt{k_{y}} \sqrt{K_{+}} l_{x} \cos{\left(\theta \right)} \left({{a_-}^\dagger} + {a_-}\right)}{2} + \frac{\sqrt{2} i \sqrt{k_{y}} \sqrt{K_{-}} l_{x} \sin{\left(\theta \right)} \left({{a_+}^\dagger} - {a_+}\right)}{2}$
# $\displaystyle p_{x} : - \frac{\sqrt{2} \hbar \sin{\left(\theta \right)} \left({{a_-}^\dagger} + {a_-}\right)}{2 \sqrt{K_{-}} l_{x}} + \frac{\sqrt{2} i \hbar \cos{\left(\theta \right)} \left({{a_+}^\dagger} - {a_+}\right)}{2 \sqrt{K_{+}} l_{x}}$
# $\displaystyle p_{y} : - \frac{\sqrt{2} \hbar \sin{\left(\theta \right)} \left({{a_+}^\dagger} + {a_+}\right)}{2 \sqrt{k_{y}} \sqrt{K_{-}} l_{x}} + \frac{\sqrt{2} i \hbar \cos{\left(\theta \right)} \left({{a_-}^\dagger} - {a_-}\right)}{2 \sqrt{k_{y}} \sqrt{K_{+}} l_{x}}$

# %% [markdown]
# # Lab Frame

# %%
kz = RDSymbol('k_z', positive=True, real=True)
Omega_z = omega_x / kz

n1 = RDSymbol('n_1', order=1, positive=True, integer=True)          # b1=n1/lx
n2 = RDSymbol('n_2', order=2, positive=True, integer=True)          # b2=n2/lx**2

H0 = ((sp.factor_terms((hbar * omega_p * ad_1 * a_1 + hbar * omega_m * ad_2 * a_2).expand()).expand() - sp.Rational(1,2) * hbar * Omega_z * sz) / (hbar * omega_x)).expand()
V1 = (sp.factor_terms(sp.Rational(1,2) * hbar * Omega_z * n1 / lx * 1/B * (x_T * sx + y_T * sy)) / (hbar * omega_x)).expand()
V2 = (sp.factor_terms(sp.Rational(1,2) * hbar * Omega_z * n2 / lx**2 * 1/B * (x_T**2  + y_T**2) * sz) / (hbar * omega_x)).expand()

H = H0 + V1 + V2

# %%
Eff_frame = EffectiveFrame(H, subspaces=[Spin])
Eff_frame.solve(max_order=2, full_diagonalization=True)
result = Eff_frame.get_H('dict_matrix')
# Out:
# The EffectiveFrame object has been initialized successfully.
#
# Effective Frame
#
# ╭────────┬─────────┬─────────────╮
# │  Name  │  Type   │  Dimension  │
# ├────────┼─────────┼─────────────┤
# │ sigma  │ Finite  │     2x2     │
# ├────────┼─────────┼─────────────┤
# │  a_+   │ Bosonic │      ∞      │
# ├────────┼─────────┼─────────────┤
# │  a_-   │ Bosonic │      ∞      │
# ╰────────┴─────────┴─────────────╯
#
# Effective Hamiltonian: 	Not computed yet. To do so, run `solve` method.
# Solving for each order: 100%|██████████| 2/2 [00:00<00:00,  2.08it/s]
# The Hamiltonian has been solved successfully. Please use the get_H method to get the result in the desired form.
# Converting to dictionary (matrix) form: 100%|██████████| 6/6 [00:00<00:00, 76.07it/s]

# %%
qubit_freq = (result[1][1] - result[1][0]).expand().subs(subs_theta).trigsimp()

# %%
sp.factor_terms((qubit_freq - 1/(2*kz)).collect(sp.sqrt(a**2+b**2)).subs(sp.sqrt(a**2+b**2), (1/kp**2 - 1/km**2).factor()).subs(a, 2 / kB * sp.sqrt(1 / (Kp*Km*ky))).collect(b).subs(subs_ab).subs(kp*km,ky).expand().factor().collect(Kp).collect(Km)).subs(kp*km,ky).subs(subs_Kp).expand().factor().subs(kp*km,ky).collect([kp,km]).collect(kB*ky**3 + 2*kB*ky**2 + kB*ky - 2*ky**2*kz).collect(kB*ky**4*kz + kB*ky**3*kz + 2*kB*ky**2*kz+kB*ky*kz+kB*kz).collect(kB*ky**2*kz+kB*kz).subs(kB*ky**5 + 2*kB*ky**4 + 2*kB*ky**3 - 2*ky**4*kz, ky**2*(kB*ky**3 + 2*kB*ky**2 + kB*ky - 2*ky**2*kz)+kB*ky**3).collect(kB*ky**3 + 2*kB*ky**2+ kB*ky -2*ky**2*kz)
# Out:
# (k_B*k_y**5*n_1**2 - 2*k_B*k_y**5*n_2*B - 2*k_B*k_y**4*k_z**2*n_2*B + 2*k_B*k_y**4*n_1**2 - 4*k_B*k_y**4*n_2*B - 4*k_B*k_y**3*k_z**2*n_2*B - 8*k_B*k_y**3*k_z*B**2 + 2*k_B*k_y**3*n_1**2 - 4*k_B*k_y**3*n_2*B - 4*k_B*k_y**2*k_z**2*n_2*B - 8*k_B*k_y**2*k_z*B**2 + 2*k_B*k_y**2*n_1**2 - 4*k_B*k_y**2*n_2*B - 4*k_B*k_y*k_z**2*n_2*B - 8*k_B*k_y*k_z*B**2 + k_B*k_y*n_1**2 - 2*k_B*k_y*n_2*B - 2*k_B*k_z**2*n_2*B - 4*k_B*k_z*B**2*k_+**4 - 4*k_B*k_z*B**2*k_-**4 - 2*k_y**4*k_z*n_1**2 - 2*k_y**2*k_z*n_1**2 + k_+**3*(k_B*k_y**2*k_z*n_1**2 - 2*k_B*k_y**2*k_z*n_2*B - 4*k_B*k_y*k_z*n_2*B - 4*k_B*k_y*B**2 - 4*k_B*k_z**2*B**2 + k_B*k_z*n_1**2 - 2*k_B*k_z*n_2*B) + k_+**2*(k_B*k_y**3*n_1**2 - 2*k_B*k_y**3*n_2*B - 2*k_B*k_y**2*k_z**2*n_2*B - 4*k_B*k_y**2*k_z*B**2 + 2*k_B*k_y**2*n_1**2 - 4*k_B*k_y**2*n_2*B - 4*k_B*k_y*k_z**2*n_2*B - 8*k_B*k_y*k_z*B**2 + k_B*k_y*n_1**2 - 2*k_B*k_y*n_2*B - 2*k_B*k_z**2*n_2*B - 4*k_B*k_z*B**2 - 2*k_y**2*k_z*n_1**2) + k_+*(k_B*k_y**4*k_z*n_1**2 - 2*k_B*k_y**4*k_z*n_2*B + k_B*k_y**3*k_z*n_1**2 - 6*k_B*k_y**3*k_z*n_2*B - 4*k_B*k_y**3*B**2 - 4*k_B*k_y**2*k_z**2*B**2 + 2*k_B*k_y**2*k_z*n_1**2 - 8*k_B*k_y**2*k_z*n_2*B - 4*k_B*k_y**2*B**2 - 4*k_B*k_y*k_z**2*B**2 + k_B*k_y*k_z*n_1**2 - 6*k_B*k_y*k_z*n_2*B - 4*k_B*k_y*B**2 - 4*k_B*k_z**2*B**2 + k_B*k_z*n_1**2 - 2*k_B*k_z*n_2*B) + k_-**3*(k_B*k_y**2*k_z*n_1**2 - 2*k_B*k_y**2*k_z*n_2*B - 4*k_B*k_y*k_z*n_2*B - 4*k_B*k_y*B**2 - 4*k_B*k_z**2*B**2 + k_B*k_z*n_1**2 - 2*k_B*k_z*n_2*B) + k_-**2*(k_B*k_y**3*n_1**2 - 2*k_B*k_y**3*n_2*B - 2*k_B*k_y**2*k_z**2*n_2*B - 4*k_B*k_y**2*k_z*B**2 + 2*k_B*k_y**2*n_1**2 - 4*k_B*k_y**2*n_2*B - 4*k_B*k_y*k_z**2*n_2*B - 8*k_B*k_y*k_z*B**2 + k_B*k_y*n_1**2 - 2*k_B*k_y*n_2*B - 2*k_B*k_z**2*n_2*B - 4*k_B*k_z*B**2 - 2*k_y**2*k_z*n_1**2) + k_-*(k_B*k_y**4*k_z*n_1**2 - 2*k_B*k_y**4*k_z*n_2*B + k_B*k_y**3*k_z*n_1**2 - 6*k_B*k_y**3*k_z*n_2*B - 4*k_B*k_y**3*B**2 - 4*k_B*k_y**2*k_z**2*B**2 + 2*k_B*k_y**2*k_z*n_1**2 - 8*k_B*k_y**2*k_z*n_2*B - 4*k_B*k_y**2*B**2 - 4*k_B*k_y*k_z**2*B**2 + k_B*k_y*k_z*n_1**2 - 6*k_B*k_y*k_z*n_2*B - 4*k_B*k_y*B**2 - 4*k_B*k_z**2*B**2 + k_B*k_z*n_1**2 - 2*k_B*k_z*n_2*B))/(8*k_B*k_z*B**2*(k_z + k_+)*(k_z + k_-)*(k_+ + k_-)*(k_+**2 + 1)*(k_-**2 + 1))

# %%
kE = sp.Symbol('k_E', positive=True, real=True)
omega_D = sp.Symbol('omega_D', positive=True, real=True)
t = sp.Symbol('t', positive=True, real=True)

E0 = - hbar * omega_x / (2 * lx) * 1/ kE**(3/2) * sp.cos(omega_D * t)
H_drive = E0 * x_T / (hbar * omega_x)   # Drive Hamiltonian in units of hbar*omega_x
H_drive
# Out:
# -cos(omega_D*t)*(sqrt(2)*sqrt(K_+)*l_x*cos(theta)*(Dagger(a_+) + a_+)/2 + sqrt(2)*I*sqrt(K_-)*l_x*sin(theta)*(Dagger(a_-) - a_-)/2)/(2*k_E**1.5*l_x)

# %%
E0
# Out:
# -hbar*omega_x*cos(omega_D*t)/(2*k_E**1.5*l_x)

# %%
Eff_drive = Eff_frame.rotate(H_drive, return_form='operator')
# Out:
# Rotating for each order: 100%|██████████| 2/2 [00:00<00:00,  8.18it/s]
# Projecting to operator form: 100%|██████████| 13/13 [01:49<00:00,  8.45s/it]

# %%
Eff_drive = Eff_frame.rotate(H_drive, return_form='operator')
# Out:
# Rotating for each order: 100%|██████████| 2/2 [00:00<00:00, 10.75it/s]
# Projecting to operator form: 100%|██████████| 13/13 [01:37<00:00,  7.53s/it]

# %%
k3 = sp.Symbol('k_3', positive=True, real=True)
result = group_by_operators(Eff_drive)[sx].factor().collect(sp.sqrt(Kp*Km*ky)*sp.cos(theta)*sp.sin(theta)).collect(Kp*sp.cos(theta)**2).collect(Km*sp.sin(theta)**2).subs(subs_theta).expand().factor().collect(sp.sqrt(a**2+b**2)).subs(sp.sqrt(a**2+b**2), (1/kp**2 - 1/km**2).factor()).subs(a, 2 / kB * sp.sqrt(1 / (Kp*Km*ky))).collect(b).subs(subs_ab).subs(kp*km,ky).expand().factor().collect(Kp).collect(Km).subs(subs_Kp).expand().factor().subs(kp*km,ky).collect([kp,km]).collect(kB*ky**2 - kB*kz**2 - ky**2*kz).subs(((kB*ky**2 - kB*kz**2 - ky**2*kz)*ky**2).expand(), (kB*ky**2 - kB*kz**2 - ky**2*kz)*ky**2).collect(kB*ky**2 - kB*kz**2 - ky**2*kz).subs((kp**2 + 1)*(km**2+1),((kp**2 + 1)*(km**2+1)).expand().subs(kp*km,ky))
result
# Out:
# -k_z*n_1*(k_B*k_y**2 - k_B*k_z**2 - k_y**2*k_z)*cos(omega_D*t)/(4*k_B*B*k_E**1.5*(-k_z + k_+)*(-k_z + k_-)*(k_z + k_+)*(k_z + k_-))

# %% [markdown]
# # Co-moving Frame

# %%
H0_expr = px**2/(2*m) + py**2/(2*m) + m/2 * (omega_x**2 + sp.Rational(1,4) * omega_c**2) * x**2 + m/2 * (omega_y**2 + sp.Rational(1,4) * omega_c**2) * y**2  + sp.Rational(1,2) * omega_c * (px * y - py * x)
H0_sym = Operator('H_0')
display_dict({
    H0_sym : H0_expr
})

display(Markdown('### Transformed Hamiltonian in the co-moving frame'))

# Co-moving Frame T = exp(i/hbar d(t) px)
# T H0 T^dag + ihbar dot(T) T^dag, TxT^dag = x - d(t)
d_sym = sp.Symbol('d', real=True)
ddt_sym = sp.Symbol('d_t', real=True)
H_transformed_dict = group_by_operators(H0_expr.subs(x, x - d_sym).expand().subs(H0_expr.expand(), H0_sym) - ddt_sym * px)
display_dict(H_transformed_dict)
# Out:
# $\displaystyle H_{0} : \frac{m \left(\omega_{x}^{2} + \frac{\omega_{x}^{2}}{4 k_{B}^{2}}\right) x^{2}}{2} + \frac{m \left(\frac{\omega_{x}^{2}}{k_{y}^{2}} + \frac{\omega_{x}^{2}}{4 k_{B}^{2}}\right) y^{2}}{2} + \frac{p_{x}^{2}}{2 m} + \frac{p_{y}^{2}}{2 m} - \frac{\omega_{x} \left(p_{x} y - p_{y} x\right)}{2 k_{B}}$
# ### Transformed Hamiltonian in the co-moving frame
# $\displaystyle 1 : \frac{d^{2} m \omega_{x}^{2}}{2} + \frac{d^{2} m \omega_{x}^{2}}{8 k_{B}^{2}}$
# $\displaystyle x : - d m \omega_{x}^{2} - \frac{d m \omega_{x}^{2}}{4 k_{B}^{2}}$
# $\displaystyle p_{x} : - d_{t}$
# $\displaystyle H_{0} : 1$
# $\displaystyle p_{y} : - \frac{d \omega_{x}}{2 k_{B}}$

# %%
# Rotating the Unperturbed Hamiltonian to the co-moving frame
H_drive = E0 * x

# Solving for d(t) in the transformed Hamiltonian such that the drive Hamiltonian is in the co-moving frame
# i.e. The driving Hamiltonian is eliminated from the transformed Hamiltonian
d = sp.nsimplify(sp.solve((H_transformed_dict[x]*x + H_drive ), d_sym)[0]).subs(subs_lenght)
d
# Out:
# -2*k_B**2*l_x*cos(omega_D*t)/(k_E**(3/2)*(4*k_B**2 + 1))

# %%
# Rotating the perturbation to the co-moving frame
V1_sym = Operator('V_1')
V2_sym = Operator('V_2')

V1_expr = sp.factor_terms(sp.Rational(1,2) * hbar * Omega_z * n1 / lx * 1/B * (x * sx + y * sy)) 
V1_transformed_dict = group_by_operators(V1_expr.subs(x, x - d_sym).expand().subs(V1_expr.expand(), V1_sym))
V2_expr = sp.factor_terms(sp.Rational(1,2) * hbar * Omega_z * n2 / lx**2 * 1/B * (x**2 + y**2) * sz)
V2_transformed_dict = group_by_operators(V2_expr.subs(x, x - d_sym).expand().subs(V2_expr.expand(), V2_sym))

display(Markdown('### Transformed Perturbation Hamiltonians in the co-moving frame'))
display(Markdown('#### First Order perturbation $V_1$'))
display_dict(V1_transformed_dict)
display(Markdown('#### First Order perturbation $V_2$'))
display_dict(V2_transformed_dict)
# Out:
# ### Transformed Perturbation Hamiltonians in the co-moving frame
# #### First Order perturbation $V_1$
# $\displaystyle V_{1} : 1$
# $\displaystyle \sigma_{1} : - \frac{n_{1} d \hbar \omega_{x}}{2 k_{z} B l_{x}}$
# #### First Order perturbation $V_2$
# $\displaystyle V_{2} : 1$
# $\displaystyle \sigma_{3} : \frac{n_{2} d^{2} \hbar \omega_{x}}{2 k_{z} B l_{x}^{2}}$
# $\displaystyle x \sigma_{3} : - \frac{n_{2} d \hbar \omega_{x}}{k_{z} B l_{x}^{2}}$

# %%
H_co_moving_drive = ((H_transformed_dict[px] * px_T + H_transformed_dict[py] * py_T ) / (hbar * omega_x)).expand()
display(H_co_moving_drive)
# Out:
# sqrt(2)*d_t*sin(theta)*Dagger(a_-)/(2*sqrt(K_-)*l_x*omega_x) + sqrt(2)*d_t*sin(theta)*a_-/(2*sqrt(K_-)*l_x*omega_x) - sqrt(2)*I*d_t*cos(theta)*Dagger(a_+)/(2*sqrt(K_+)*l_x*omega_x) + sqrt(2)*I*d_t*cos(theta)*a_+/(2*sqrt(K_+)*l_x*omega_x) + sqrt(2)*d*sin(theta)*Dagger(a_+)/(4*k_B*sqrt(k_y)*sqrt(K_-)*l_x) + sqrt(2)*d*sin(theta)*a_+/(4*k_B*sqrt(k_y)*sqrt(K_-)*l_x) - sqrt(2)*I*d*cos(theta)*Dagger(a_-)/(4*k_B*sqrt(k_y)*sqrt(K_+)*l_x) + sqrt(2)*I*d*cos(theta)*a_-/(4*k_B*sqrt(k_y)*sqrt(K_+)*l_x)

# %%
Eff_co_moving_drive = Eff_frame.rotate(H_co_moving_drive, return_form='operator')
# Out:
# Rotating for each order: 100%|██████████| 2/2 [00:00<00:00,  9.00it/s]
# Projecting to operator form:   0%|          | 0/13 [23:53<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 Eff_co_moving_drive = Eff_frame.rotate(H_co_moving_drive, return_form='operator')
#
# File ~/PhD/Python/Packages/PySW/SymPT/solver.py:728, in EffectiveFrame.rotate(self, expr, max_order, return_form)
#     724     extra = return_form.split(
#     725         '_')[1] if '_' in return_form else self.__return_form
#     726     return_form = 'dict' + f'_{extra}'
# --> 728 return self.__prepare_result(result, return_form)
#
# File ~/PhD/Python/Packages/PySW/SymPT/solver.py:560, in EffectiveFrame.__prepare_result(self, O_final, return_form)
#     558 if return_form == 'operator':
#     559     if self.subspaces is not None:
# --> 560         O_final_projected = np_sum([self.__composite_basis.project(mul_group.fn) * Mul(
#     561             *mul_group.inf).simplify() for mul_group in tqdm(O_final.expr, desc='Projecting to operator form')])
#     563         return O_final_projected
#     564     O_final_projected = np_sum([mul_group.fn[0] * Mul(
#     565         *mul_group.inf).simplify() for mul_group in tqdm(O_final.expr, desc='Projecting to operator form')])
#
# File ~/PhD/Python/Packages/PySW/SymPT/classes.py:1300, in RDCompositeBasis.project(self, to_be_projected)
#    1276 def project(self, to_be_projected):
#    1277     """
#    1278     Projects a given matrix onto the composite basis.
#    1279
#    (...)
#    1298     the `basis_ling_alg_norm`.
#    1299     """
# -> 1300     basis_coeffs = np_vectorize(cancel)(np_trace([matrix.T.conjugate() @ to_be_projected for matrix in self.basis_matrices],
#    1301                                                  # Compute the coefficients of the input matrix in terms of the composite basis elements.
#    1302                                                  axis1=1, axis2=2))
#    1304     # Normalize the coefficients using the `basis_ling_alg_norm`.
#    1305     basis_coeffs /= self.basis_ling_alg_norm
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2470, in vectorize.__call__(self, *args, **kwargs)
#    2467     self._init_stage_2(*args, **kwargs)
#    2468     return self
# -> 2470 return self._call_as_normal(*args, **kwargs)
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2463, in vectorize._call_as_normal(self, *args, **kwargs)
#    2460     vargs = [args[_i] for _i in inds]
#    2461     vargs.extend([kwargs[_n] for _n in names])
# -> 2463 return self._vectorize_call(func=func, args=vargs)
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2553, in vectorize._vectorize_call(self, func, args)
#    2550 # Convert args to object arrays first
#    2551 inputs = [asanyarray(a, dtype=object) for a in args]
# -> 2553 outputs = ufunc(*inputs)
#    2555 if ufunc.nout == 1:
#    2556     res = asanyarray(outputs, dtype=otypes[0])
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/polytools.py:7213, in cancel(f, _signsimp, *gens, **args)
#    7210                 pass
#    7211         return f.xreplace(dict(reps))
# -> 7213 c, (P, Q) = 1, F.cancel(G)
#    7214 if opt.get('polys', False) and 'gens' not in opt:
#    7215     opt['gens'] = R.symbols
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/rings.py:2242, in PolyElement.cancel(self, g)
#    2239 domain = ring.domain
#    2241 if not (domain.is_Field and domain.has_assoc_Ring):
# -> 2242     _, p, q = f.cofactors(g)
#    2243 else:
#    2244     new_ring = ring.clone(domain=domain.get_ring())
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/rings.py:2158, in PolyElement.cofactors(f, g)
#    2155     return h, cff, cfg
#    2157 J, (f, g) = f.deflate(g)
# -> 2158 h, cff, cfg = f._gcd(g)
#    2160 return (h.inflate(J), cff.inflate(J), cfg.inflate(J))
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/rings.py:2193, in PolyElement._gcd(f, g)
#    2191     return f._gcd_ZZ(g)
#    2192 else: # TODO: don't use dense representation (port PRS algorithms)
# -> 2193     return ring.dmp_inner_gcd(f, g)
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/compatibility.py:667, in IPolys.dmp_inner_gcd(self, f, g)
#     666 def dmp_inner_gcd(self, f, g):
# --> 667     H, F, G = dmp_inner_gcd(self.to_dense(f), self.to_dense(g), self.ngens-1, self.domain)
#     668     return (self.from_dense(H), self.from_dense(F), self.from_dense(G))
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/euclidtools.py:1598, in dmp_inner_gcd(f, g, u, K)
#    1595     return dup_inner_gcd(f, g, K)
#    1597 J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1598 h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1600 return (dmp_inflate(h, J, u, K),
#    1601         dmp_inflate(cff, J, u, K),
#    1602         dmp_inflate(cfg, J, u, K))
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/euclidtools.py:1571, in _dmp_inner_gcd(f, g, u, K)
#    1568     except HeuristicGCDFailed:
#    1569         pass
# -> 1571 return dmp_rr_prs_gcd(f, g, u, K)
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/euclidtools.py:1060, in dmp_rr_prs_gcd(f, g, u, K)
#    1057 if not u:
#    1058     return dup_rr_prs_gcd(f, g, K)
# -> 1060 result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1062 if result is not None:
#    1063     return result
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/euclidtools.py:912, in _dmp_rr_trivial_gcd(f, g, u, K)
#     910     return dmp_one(u, K), f, g
#     911 elif query('USE_SIMPLIFY_GCD'):
# --> 912     return _dmp_simplify_gcd(f, g, u, K)
#     913 else:
#     914     return None
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/euclidtools.py:954, in _dmp_simplify_gcd(f, g, u, K)
#     952         G = dmp_content(g, u, K)
#     953     else:
# --> 954         F = dmp_content(f, u, K)
#     955         G = dmp_LC(g, K)
#     957 v = u - 1
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/euclidtools.py:1812, in dmp_content(f, u, K)
#    1809     return cont
#    1811 for c in f[1:]:
# -> 1812     cont = dmp_gcd(cont, c, v, K)
#    1814     if dmp_one_p(cont, v, K):
#    1815         break
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/euclidtools.py:1639, in dmp_gcd(f, g, u, K)
#    1622 def dmp_gcd(f, g, u, K):
#    1623     """
#    1624     Computes polynomial GCD of `f` and `g` in `K[X]`.
#    1625
#    (...)
#    1637
#    1638     """
# -> 1639     return dmp_inner_gcd(f, g, u, K)[0]
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/euclidtools.py:1598, in dmp_inner_gcd(f, g, u, K)
#    1595     return dup_inner_gcd(f, g, K)
#    1597 J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1598 h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1600 return (dmp_inflate(h, J, u, K),
#    1601         dmp_inflate(cff, J, u, K),
#    1602         dmp_inflate(cfg, J, u, K))
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/euclidtools.py:1571, in _dmp_inner_gcd(f, g, u, K)
#    1568     except HeuristicGCDFailed:
#    1569         pass
# -> 1571 return dmp_rr_prs_gcd(f, g, u, K)
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/euclidtools.py:1065, in dmp_rr_prs_gcd(f, g, u, K)
#    1062 if result is not None:
#    1063     return result
# -> 1065 fc, F = dmp_primitive(f, u, K)
#    1066 gc, G = dmp_primitive(g, u, K)
#    1068 h = dmp_subresultants(F, G, u, K)[-1]
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/euclidtools.py:1837, in dmp_primitive(f, u, K)
#    1823 def dmp_primitive(f, u, K):
#    1824     """
#    1825     Returns multivariate content and a primitive polynomial.
#    1826
#    (...)
#    1835
#    1836     """
# -> 1837     cont, v = dmp_content(f, u, K), u - 1
#    1839     if dmp_zero_p(f, u) or dmp_one_p(cont, v, K):
#    1840         return cont, f
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/euclidtools.py:1812, in dmp_content(f, u, K)
#    1809     return cont
#    1811 for c in f[1:]:
# -> 1812     cont = dmp_gcd(cont, c, v, K)
#    1814     if dmp_one_p(cont, v, K):
#    1815         break
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/euclidtools.py:1639, in dmp_gcd(f, g, u, K)
#    1622 def dmp_gcd(f, g, u, K):
#    1623     """
#    1624     Computes polynomial GCD of `f` and `g` in `K[X]`.
#    1625
#    (...)
#    1637
#    1638     """
# -> 1639     return dmp_inner_gcd(f, g, u, K)[0]
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/euclidtools.py:1598, in dmp_inner_gcd(f, g, u, K)
#    1595     return dup_inner_gcd(f, g, K)
#    1597 J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1598 h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1600 return (dmp_inflate(h, J, u, K),
#    1601         dmp_inflate(cff, J, u, K),
#    1602         dmp_inflate(cfg, J, u, K))
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/euclidtools.py:1571, in _dmp_inner_gcd(f, g, u, K)
#    1568     except HeuristicGCDFailed:
#    1569         pass
# -> 1571 return dmp_rr_prs_gcd(f, g, u, K)
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/euclidtools.py:1068, in dmp_rr_prs_gcd(f, g, u, K)
#    1065 fc, F = dmp_primitive(f, u, K)
#    1066 gc, G = dmp_primitive(g, u, K)
# -> 1068 h = dmp_subresultants(F, G, u, K)[-1]
#    1069 c, _, _ = dmp_rr_prs_gcd(fc, gc, u - 1, K)
#    1071 _, h = dmp_primitive(h, u, K)
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/euclidtools.py:549, in dmp_subresultants(f, g, u, K)
#     529 def dmp_subresultants(f, g, u, K):
#     530     """
#     531     Computes subresultant PRS of two polynomials in `K[X]`.
#     532
#    (...)
#     547
#     548     """
# --> 549     return dmp_inner_subresultants(f, g, u, K)[0]
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/euclidtools.py:512, in dmp_inner_subresultants(f, g, u, K)
#     507 f, g, m, d = g, h, k, m - k
#     509 b = dmp_mul(dmp_neg(lc, v, K),
#     510             dmp_pow(c, d, v, K), v, K)
# --> 512 h = dmp_prem(f, g, u, K)
#     513 h = [ dmp_quo(ch, b, v, K) for ch in h ]
#     515 lc = dmp_LC(g, K)
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/densearith.py:1237, in dmp_prem(f, g, u, K)
#    1234 lc_r = dmp_LC(r, K)
#    1235 j, N = dr - dg, N - 1
# -> 1237 R = dmp_mul_term(r, lc_g, 0, u, K)
#    1238 G = dmp_mul_term(g, lc_r, j, u, K)
#    1239 r = dmp_sub(R, G, u, K)
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/densearith.py:184, in dmp_mul_term(f, c, i, u, K)
#     182     return dmp_zero(u)
#     183 else:
# --> 184     return [ dmp_mul(cf, c, v, K) for cf in f ] + dmp_zeros(i, v, K)
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
#     [... skipping similar frames: dmp_mul at line 828 (4 times)]
#
# File ~/miniconda3/envs/pysw/lib/python3.13/site-packages/sympy/polys/densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
# KeyboardInterrupt:

# %%
kp_2_val = sp.nsimplify(1/ (1/2 * (1 + 1/ky**2 + 1/kB**2 + 1/k3**2))).factor()
km_2_val = sp.nsimplify(1/ (1/2 * (1 + 1/ky**2 + 1/kB**2 - 1/k3**2))).factor()

# %%
expr1 = (1/kp_2_val + 1/km_2_val -1).factor()
expr2 = (1/kp**2 + 1/km**2-1).factor().subs(kp*km,ky)

display(expr1)
display(expr2)

subs_sol = {
    expr2.as_numer_denom()[0] : sp.solve(expr1 - expr2, expr2.as_numer_denom()[0])[0].factor().subs(kp*km,ky)
}

display_dict(subs_sol)

Eff_Drive_sy = group_by_operators(Eff_co_moving_drive)[sy].factor().collect(sp.sqrt(Kp*Km*ky)*sp.cos(theta)*sp.sin(theta)).collect(Kp*sp.cos(theta)**2).collect(Km*sp.sin(theta)**2).subs(subs_theta).expand().factor().collect(sp.sqrt(a**2+b**2)).subs(sp.sqrt(a**2+b**2), (1/kp**2 - 1/km**2).factor()).subs(a, 2 / kB * sp.sqrt(1 / (Kp*Km*ky))).collect(b).subs(subs_ab).subs(kp*km,ky).expand().factor().collect(Kp).collect(Km).subs(subs_Kp).expand().factor().subs(kp*km,ky).collect(kB**2).collect(kz**2*ky).subs(subs_sol).factor().collect(kB*ky**2*kz).collect(kB)
display(Eff_Drive_sy)
# Out:
# (k_B**2 + k_y**2)/(k_B**2*k_y**2)
# (-k_y**2 + k_+**2 + k_-**2)/k_y**2
# $\displaystyle - k_{y}^{2} + k_{+}^{2} + k_{-}^{2} : \frac{k_{B}^{2} + k_{y}^{2}}{k_{B}^{2}}$
# -n_1*d_t*(k_B**2*(2*k_y**2 - 2*k_z**2) + k_B*k_y**2*k_z*(-k_z**2 - 1) - k_y**2*k_z**2)/(4*k_B**2*B*l_x*omega_x*(-k_z + k_+)*(-k_z + k_-)*(k_z + k_+)*(k_z + k_-))

# %%
expr1 = (1/kp_2_val + 1/km_2_val +1).factor()
expr2 = (1/kp**2 + 1/km**2+1).factor().subs(kp*km,ky)

display(expr1)
display(expr2)

subs_sol = {
    expr2.as_numer_denom()[0] : sp.solve(expr1 - expr2, expr2.as_numer_denom()[0])[0].factor().subs(kp*km,ky)
}

display_dict(subs_sol)

Eff_Drive_sx = group_by_operators(Eff_co_moving_drive)[sx].factor().collect(sp.sqrt(Kp*Km*ky)*sp.cos(theta)*sp.sin(theta)).collect(Kp*sp.cos(theta)**2).collect(Km*sp.sin(theta)**2).subs(subs_theta).expand().factor().collect(sp.sqrt(a**2+b**2)).subs(sp.sqrt(a**2+b**2), (1/kp**2 - 1/km**2).factor()).subs(a, 2 / kB * sp.sqrt(1 / (Kp*Km*ky))).collect(b).subs(subs_ab).subs(kp*km,ky).expand().factor().collect(Kp).collect(Km).subs(subs_Kp).expand().factor().subs(kp*km,ky).expand().factor().collect(kB*kz**2).subs(subs_sol).factor().collect(kB**2*ky**2).collect(kB*kz) + V1_transformed_dict[sx] / (hbar * omega_x)
display(Eff_Drive_sx)
# Out:
# (2*k_B**2*k_y**2 + k_B**2 + k_y**2)/(k_B**2*k_y**2)
# (k_y**2 + k_+**2 + k_-**2)/k_y**2
# $\displaystyle k_{y}^{2} + k_{+}^{2} + k_{-}^{2} : \frac{2 k_{B}^{2} k_{y}^{2} + k_{B}^{2} + k_{y}^{2}}{k_{B}^{2}}$
# -n_1*d/(2*k_z*B*l_x) - n_1*d*(k_B**2*k_y**2*(2*k_z**2 - 2) + k_B*k_z*(k_y**2 + k_z**2) + k_y**2*k_z**2)/(8*k_B**3*B*l_x*(-k_z + k_+)*(-k_z + k_-)*(k_z + k_+)*(k_z + k_-))

# %%
H_Eff_Drive = Eff_Drive_sy * sy + Eff_Drive_sx * sx
H_Eff_Drive.subs(d_sym, d).subs(ddt_sym, sp.diff(d, t))
# Out:
# -n_1*omega_D*(k_B**2*(2*k_y**2 - 2*k_z**2) + k_B*k_y**2*k_z*(-k_z**2 - 1) - k_y**2*k_z**2)*sin(omega_D*t)*sigma_2/(2*B*k_E**(3/2)*omega_x*(4*k_B**2 + 1)*(-k_z + k_+)*(-k_z + k_-)*(k_z + k_+)*(k_z + k_-)) + (k_B**2*n_1*cos(omega_D*t)/(k_z*B*k_E**(3/2)*(4*k_B**2 + 1)) + n_1*(k_B**2*k_y**2*(2*k_z**2 - 2) + k_B*k_z*(k_y**2 + k_z**2) + k_y**2*k_z**2)*cos(omega_D*t)/(4*k_B*B*k_E**(3/2)*(4*k_B**2 + 1)*(-k_z + k_+)*(-k_z + k_-)*(k_z + k_+)*(k_z + k_-)))*sigma_1
